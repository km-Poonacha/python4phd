# %% [markdown]
# # Lesson 4 - Web API

# %% [markdown]
# ## Requesting information from the web

# %% [markdown]
# ### Python 'requests' module.
# * This module provides functions to send a HTTP request and get the response from the server
# * Requests is a third party module. If not installed, we will need to do "pip install requests" in the mac terminal or in the command pronpt of windows.
# * http://docs.python-requests.org/en/master/user/quickstart/#make-a-request

# %% [markdown]
# ### Using 'requests' module
# Use the requests module to make a HTTP request to http://www.github.com/ibm
# - Check the status of the request
# - Display the response header information
#
# <center>
#     <img src="HTTPresponse.gif"  width="200" title="HTTP response packet">
# </center>

# %% [markdown]
# *Get status code for the request*

# %%
import requests 
url = 'http://www.github.com/ibm'
response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %% [markdown]
# *Get header information*

# %%
import requests 
url = 'http://www.github.com/ibm'
response = requests.get(url)

print(response.status_code)

if response.status_code == 200:
    print('Response status - OK ')
    print(response.headers)
else: 
    print('Error making the HTTP request ',response.status_code  )

# %% [markdown]
# *Get the body Information*

# %%
import requests 
url = 'http://www.github.com/ibm'
response = requests.get(url)

print(response.status_code)

if response.status_code == 200:
    print('Response status - OK ')
    print(response.text)
else: 
    print('Error making the HTTP request ',response.status_code  )

# %% [markdown]
# ## Using a Web API to Collect Data
# * An application programming interface is a set of functions that you call to get access to some service.
# * An API is basically a list of functions and datatsructures for interfacting with websites's data.
#
# The way these work is similar to viewing a web page. When you point your browser to a website, you do it with a URL (http://www.github.com/ibm for instance). Github sends you back data containing HTML, CSS, and Javascript. Your browser uses this data to construct the page that you see. The API works similarly, you request data with a URL (http://api.github.com/org/ibm), but instead of getting HTML and such, you get data formatted as JSON.

# %% [markdown]
# ### Access data using web APIs
#
# *Write a program to access all the public OSS projects hosted by IBM on github.com using the web apis*

# %% [markdown]
# #### Step 1: Access the Web API service and check rate limits

# %%
import requests
    
url = "https://api.github.com/orgs/ibm"
response = requests.get(url)

if response.status_code == 200:
    print('Response status - OK ')
    print(response.headers['X-RateLimit-Remaining'])
else:
    print('Error making the HTTP request ',response.status_code  )
# Out:
# Response status - OK
# 53

# %% [markdown]
# #### Step 2: Authentication (if required)
# Authenticate requests to increase the API request limit. Access data that requires authentication.
#
# ##### Basic Authentication
# * Pass the userid and password as parameters in the response.get  function
# * Little risky and prone to hacking. Create dummy user ID and password
#
# ##### OAUTH
# * OAuth 2 is an authorization framework that enables a user to connect to their account using a third party application
# * While this is more secure thant the basic authentication (i.e. passing the userid and password while you make a http request), it is a little more difficult to code.
# * It needs a personal token and a consumer key to be generated and passed to the webserver
#
# Unfortunately different websites have different ways of generating and using the token and consumer keys. Hence we will need to write the authorization code for each website seperately. HOwever, every website provides detailed information on how you can generate and send the token and keys.

# %%
import requests
    
def GithubAPI(url):
    """ Make a HTTP request for the given URL and send the response body
    back to the calling function"""
    # Use basic authentication
    response = requests.get(url, auth=("ENTER USER ID","ENTER PASSWORD"))
    if response.status_code == 200:
        print('Response status - OK ')
        print(response.headers['X-RateLimit-Remaining'])
        return response.text
    else:
        print('Error making the HTTP request ',response.status_code  )
        return None

def main():
    url = "https://api.github.com/orgs/ibm"
    txt_response = GithubAPI(url)
    
    if txt_response:
        print(txt_response)

main()

# %% [markdown]
# #### Step 3: Parse the response
# The *json* module gives us functions to convert the JSON response to a python readable data structure.
#
# *Write a program to get the number of OSS projects started by IBM*

# %%
import requests
import json

def GithubAPI(url):
    """ Make a HTTP request for the given URL and send the response body
    back to the calling function"""
    response = requests.get(url)
    if response.status_code == 200:
        print('Response status - OK ')
        return response.json()
    else:
        print('Error making the HTTP request ',response.status_code  )
        return None

def main():
    url = "https://api.github.com/orgs/ibm"
    txt_response = GithubAPI(url)
    
    if txt_response:
        print('The number of public repos are : ',txt_response['public_repos'])

main()
# Out:
# Response status - OK
# The number of public repos are :  851

# %% [markdown]
# #### Step 3: Follow the url information from the Web API to find what you need
#
# *Let us collect the information regarding the different projects started by IBM *

# %%
import requests
import json
        
def GithubAPI(url):
    """ Make a HTTP request for the given URL and send the response body
    back to the calling function"""
    response = requests.get(url, auth("ENTER USER ID","ENTER PASSWORD"))
    if response.status_code == 200:
        print('Response status - OK ')
        return response.json()
    else:
        print('Error making the HTTP request ',response.status_code  )
        return None

def main():
    url = "https://api.github.com/orgs/ibm"
    response_json = GithubAPI(url)
    
    if response_json:
        print('The number of public repos are : ',response_json['public_repos'])
        repo_url = response_json['repos_url']
        repo_response = GithubAPI(repo_url)
        for repo in repo_response:
            print([repo['id'],repo['name']])
        
main()
# Out:
# Response status - OK
# The number of public repos are :  851
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']

# %% [markdown]
# #### Step 4: Paginate to get data from other pages
#
# *Traverse the pages if the data is spread across multiple pages*

# %%
import requests
import json
        
def GithubAPI(url):
    """ Make a HTTP request for the given URL and send the response body
    back to the calling function"""
    response = requests.get(url, auth = ("ENTER USER ID","ENTER PASSWORD"))
    if response.status_code == 200:
        print('Response status - OK ')
        return response.json()
    else:
        print('Error making the HTTP request ',response.status_code  )
        return None

def main():
    url = "https://api.github.com/orgs/ibm"
    response_json = GithubAPI(url)
    
    if response_json:
        print('The number of public repos are : ',response_json['public_repos'])
        repo_url = response_json['repos_url']
        total_no =  response_json['public_repos']
        per_page = 100
        page_count = 1
        while page_count < total_no/100:
            #Display 100 repos per page and traverse the pages untill we get the last page
            page_url = repo_url+"?per_page=100&page_no="+str(page_count)
            print(page_url)
            repo_response = GithubAPI(page_url)
            # Increment page number
            page_count = page_count+1
            for repo in repo_response:
                print([repo['id'],repo['name']])
                
main()
# Out:
# Response status - OK
# The number of public repos are :  851
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=1
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=2
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=3
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=4
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=5
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=6
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=7
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=8
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']

# %% [markdown]
# ## 3. Write a CSV
#
# Lets try to write the repos into a CSV file.

# %% [markdown]
# *Write a code to append data row wise to a csv file*

# %%
import csv
WRITE_CSV = "C:/Users/kmpoo/Dropbox/HEC/Teaching/Python for PhD Mar 2018/python4phd/Session 2/ipython/Repo_csv.csv"
with open(WRITE_CSV, 'at',encoding = 'utf-8', newline='') as csv_obj:
    write = csv.writer(csv_obj) # Note it is csv.writer not reader
    
    write.writerow(['REPO ID','REPO NAME'])

# %% [markdown]
# *What do you think will happen if we use 'wt' as mode instead of 'at' ?*

# %% [markdown]
# *Write a program so that you save the IBM repositories into the CSV file. So that each row is a new repository and column 1 is the ID and column 2 is the name*

# %%
#Enter code here

import requests
import json
import csv

WRITE_CSV = "C:/Users/kmpoo/Dropbox/HEC/Teaching/Python for PhD Mar 2018/python4phd/Session 2/ipython/Repo_csv.csv"

def appendcsv(data_list):
    with open(WRITE_CSV, 'at',encoding = 'utf-8', newline='') as csv_obj:
        write = csv.writer(csv_obj) # Note it is csv.writer not reader 
        write.writerow(data_list)
        
def GithubAPI(url):
    """ Make a HTTP request for the given URL and send the response body
    back to the calling function"""
    response = requests.get(url, auth = ("ENTER USER ID","ENTER PASSWORD"))
    if response.status_code == 200:
        print('Response status - OK ')
        return response.json()
    else:
        print('Error making the HTTP request ',response.status_code  )
        return None

def main():
    url = "https://api.github.com/orgs/ibm"
    response_json = GithubAPI(url)
    
    if response_json:
        print('The number of public repos are : ',response_json['public_repos'])
        repo_url = response_json['repos_url']
        total_no =  response_json['public_repos']
        per_page = 100
        page_count = 1
        while page_count < total_no/100:
            #Display 100 repos per page and traverse the pages untill we get the last page
            page_url = repo_url+"?per_page=100&page_no="+str(page_count)
            print(page_url)
            repo_response = GithubAPI(page_url)
            # Increment page number
            page_count = page_count+1
            for repo in repo_response:
                print([repo['id'],repo['name']])
                appendcsv([repo['id'],repo['name']])
                
                
main()
# Out:
# Response status - OK
# The number of public repos are :  851
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=1
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=2
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=3
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=4
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=5
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=6
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=7
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
# https://api.github.com/orgs/IBM/repos?per_page=100&page_no=8
# Response status - OK
# [16753297, 'ibm.github.io']
# [56264636, 'BluePic']
# [57317846, 'SparkMultiuserBenchmark']
# [58493465, 'owplan']
# [60423506, 'otc-slack-broker']
# [60423713, 'otc-pagerduty-broker']
# [60423751, 'otc-saucelabs-broker']
# [60423790, 'node-nano-doc-updater']
# [60423820, 'node-log4js-qradar-syslog-appender']
# [60423844, 'node-swagger-ui-middleware']
# [61070405, 'xlc-community-edition-dockerfile']
# [63453689, 'ObjectizedTextInput']
# [70183924, 'ibm-cloud-functions-serverless-iot-openfridge']
# [70769104, 'CognitiveConcierge']
# [71903006, 'message-catalog-manager']
# [71910492, 'node-qradar-audit-logs-middleware']
# [72784561, 'ibm-cloud-functions-serverless-ocr-openchecks']
# [73958621, 'swift-enterprise-demo']
# [75079910, 'pyxcli']
# [76040722, 'watson-murder-mystery']
# [76064346, 'logmet-client-njs']
# [78024241, 'flocker-driver']
# [78669724, 'node-i18n-utilities']
# [81587476, 'ibm-cloud-functions-data-processing-message-hub']
# [81587591, 'ibm-cloud-functions-data-processing-cloudant']
# [81587695, 'ibm-cloud-functions-serverless-apis']
# [82159521, 'serverless-home-automation']
# [82206588, 'openwhisk-getting-started-template']
# [82599303, 'air-traffic-control']
# [82961142, 'ibm-cloud-functions-action-trigger-rule']
# [82961246, 'ibm-cloud-functions-polyglot-development']
# [83486651, 'deploy-react-kubernetes']
# [83591253, 'container-service-gitlab-sample']
# [83647324, 'PodcastDownloader']
# [83845804, 'og']
# [84106057, 'container-service-getting-started-wt']
# [84123252, 'ibm-cloud-functions-message-hub-trigger']
# [84123273, 'ibm-cloud-functions-cloudant-trigger']
# [84123282, 'ibm-cloud-functions-rest-api-trigger']
# [84130568, 'watson-online-store']
# [84220732, 'loopback-in-five']
# [84610045, 'cf-icd-plugin']
# [84883233, 'Scalable-WordPress-deployment-on-Kubernetes']
# [84884505, 'Scalable-Cassandra-deployment-on-Kubernetes']
# [84909201, 'swift-install']
# [84909370, 'swift-kitura-helloworld']
# [84909452, 'swift-sandbox']
# [84909569, 'swift-bluemix-dev-cli']
# [85362611, 'container-journey-template']
# [85910055, 'dsx-twitter-auto-analysis']
# [86095045, 'Kubernetes-container-service-GitLab-sample']
# [86702277, 'elasticsearch-spark-recommender']
# [86728214, 'todo-list-fabric']
# [86862739, 'Java-MicroProfile-on-Kubernetes']
# [86864979, 'ubiquity']
# [86865038, 'ubiquity-k8s']
# [86865070, 'ubiquity-docker-plugin']
# [87240044, 'GameOn-Java-Microservices-on-Kubernetes']
# [87472445, 'acme-freight']
# [87472517, 'acme-freight-controller']
# [87472574, 'acme-freight-erp']
# [87472629, 'acme-freight-mobile']
# [87472701, 'acme-freight-recommendation']
# [87472751, 'acme-freight-webui']
# [88087472, 'powerai-market-sentiment']
# [88089340, 'OpenWhisk-on-Kubernetes']
# [88342252, 'rocc-software']
# [88342295, 'perfect-chisel']
# [88342318, 'hdl-tools']
# [88786807, 'websphere-api-connect']
# [88885593, 'starcraft2-replay-analysis']
# [88887653, 'personal-wealth-portfolio-mgt-bot']
# [88990534, 'node-log4js-logmet-appender']
# [89129284, 'janusgraph-utils']
# [89307812, 'vr-speech-sandbox-vive']
# [89406689, 'Hybrid-Cloud-Applications-and-Services']
# [89407699, 'spring-boot-microservices-on-kubernetes']
# [89522063, 'xlf-community-edition-dockerfile']
# [90167868, 'ibm-cloud-devops']
# [90424090, 'todo-list-fabricV1']
# [90553046, 'watson-banking-chatbot']
# [90677849, 'Microservices-deployment-with-PaaS-Containers-and-Serverless-Platforms']
# [91008551, 'Spark-on-zOS']
# [91022329, 'expressjs-openwhisk']
# [91115320, 'tjbot-sports-buddy']
# [91738423, 'Restful-APIs-using-zOS-Connect']
# [92070211, 'sms-analysis-with-wks']
# [92088076, 'zOS-Application-Discovery-and-Delivery-Intelligence']
# [92344109, 'microservices-traffic-management-using-istio']
# [92867444, 'Cloud-Native-Workloads-on-LinuxONE']
# [92877188, 'spring-boot-continuous-delivery']
# [92913589, 'watson-discovery-news-alerting']
# [93082188, 'Microservices-with-JHipster-and-Spring-Boot']
# [93082771, 'vr-speech-sandbox-cardboard']
# [93083461, 'resilient-java-microservices-with-istio']
# [93193327, 'pino-couch']
# [93460373, 'CognitiveIoT']
# [93775722, 'Predictive-Market-Stress-Testing']
# [93879293, 'spring-boot-continuous-delivery-admin']
# [93895815, 'watson-multimedia-analyzer']
