# %%
import csv
import nltk
import random

def feature_extractor(word):
    start_letter = word[0]
    last_letter = word[-2:]
    no_letters = len(word)
    percentage_vowels = 0
    no_vowels = 0
    for letter in word:
        if letter in ['a','e','i','o','u']:
            no_vowels = no_vowels + 1
    if no_vowels:
        percentage_vowels = no_vowels/len(word)
    return {'start_letter' : start_letter,'last_letter' : last_letter, 'no_letters' : no_letters,'percentage_vowels': percentage_vowels}

def ML_train(LABEL_CSV):
    feature_list = []
    train_list =[]
    test_list = []
    #feature_row = []
    with open (LABEL_CSV,'rt',encoding='utf-8') as labelobj:
        label_list=csv.reader(labelobj)
        for label_data in label_list:
            word_features = feature_extractor(label_data[0])
            if int(label_data[1]) >= 0:
                feature_row = [word_features,'positive']
            else:
                feature_row = [word_features,'negative']
            feature_list.append(feature_row)
    random.shuffle(feature_list)    
    train_list = feature_list[:1500]
    test_list = feature_list[:-1500]
    classifier = nltk.NaiveBayesClassifier.train(train_list)
    print('Test accuracy of the classifier = ',nltk.classify.accuracy(classifier, test_list))
    print(classifier.show_most_informative_features())
    return classifier
    
    
def main():
    sentiment_csv = "C:/Users/kmpoo/Dropbox/HEC/Teaching/Python for PhD Mar 2018/python4phd/Session 3/Sent/word_sentiment.csv"
    print(feature_extractor('poonacha'))
    classifier = ML_train(sentiment_csv)
    # why not pass the word directly to ML_train ?
    print(classifier.classify(feature_extractor('trump')))
    # Can you tell me why it changes when we run this again ? 
    
          
main()
# Out:
# {'start_letter': 'p', 'last_letter': 'ha', 'no_letters': 8, 'percentage_vowels': 0.5}
# Test accuracy of the classifier =  0.7229038854805726
# Most Informative Features
#             start_letter = 'j'            positi : negati =      6.6 : 1.0
#             start_letter = 'y'            positi : negati =      5.1 : 1.0
#              last_letter = 'sh'           negati : positi =      5.1 : 1.0
#             start_letter = 'u'            negati : positi =      5.0 : 1.0
#             start_letter = 'd'            negati : positi =      4.5 : 1.0
#              last_letter = 'nd'           positi : negati =      3.5 : 1.0
#              last_letter = 'ck'           negati : positi =      3.5 : 1.0
#             start_letter = 'g'            positi : negati =      3.2 : 1.0
#              last_letter = 'ds'           positi : negati =      3.0 : 1.0
#             start_letter = 'k'            positi : negati =      2.9 : 1.0
# None
# negative

# %%
import csv
import nltk
import random

def feature_extractor(word):
    start_letter = word[0]
    last_letter = word[-1]
    seclast_letter = word[-2]
    no_letters = len(word)
    percentage_vowels = 0
    no_vowels = 0
    for letter in word:
        if letter in ['a','e','i','o','u']:
            no_vowels = no_vowels + 1
    if no_vowels:
        percentage_vowels = no_vowels/len(word)
    return {'start_letter' : start_letter,'last_letter' : last_letter}

def ML_train(LABEL_CSV):
    feature_list = []
    train_list =[]
    test_list = []
    #feature_row = []
    with open (LABEL_CSV,'rt',encoding='utf-8') as labelobj:
        label_list=csv.reader(labelobj)
        for label_data in label_list:
            word_features = feature_extractor(label_data[0])
            if int(label_data[1]) >= 0:
                feature_row = [word_features,'positive']
            else:
                feature_row = [word_features,'negative']
            feature_row.append(label_data[0])
            feature_list.append(feature_row)
    random.shuffle(feature_list)    
    train_list = feature_list[:1800]
    nt = [[features_dict[0], features_dict[1]] for features_dict in   train_list ]
    #print(nt)
    #devtest_list = feature_list[1200:1800]
    test_list = feature_list[:-1800]
    classifier = nltk.NaiveBayesClassifier.train(nt)
    print('Test accuracy of the classifier = ',nltk.classify.accuracy(classifier, nt))
    print(classifier.show_most_informative_features())
    dev_test(classifier, test_list)
    return classifier
    
def dev_test(classifier, devtest_list):
    dt = [[features_dict[0], features_dict[1]] for features_dict in   devtest_list ]
    for devtest_word in devtest_list:
        calc_sentiment = classifier.classify(devtest_word[0])
        if calc_sentiment != devtest_word[1]:
            print('Name : ',devtest_word[2],' Calc_sentiment : ',calc_sentiment, ' Actual_sentiment : ',devtest_word[1])
    
    
def main():
    sentiment_csv = "C:/Users/kmpoo/Dropbox/HEC/Teaching/Python for PhD Mar 2018/python4phd/Session 3/Sent/word_sentiment.csv"
    print(feature_extractor('poonacha'))
    classifier = ML_train(sentiment_csv)
    # why not pass the word directly to ML_train ?
    print(classifier.classify(feature_extractor('poonacha')))
    
    
          
main()
# Out:
# {'start_letter': 'p', 'last_letter': 'a'}
# Test accuracy of the classifier =  0.6788888888888889
# Most Informative Features
#              last_letter = 'w'            positi : negati =      6.8 : 1.0
#             start_letter = 'd'            negati : positi =      5.4 : 1.0
#              last_letter = 'o'            positi : negati =      4.8 : 1.0
#             start_letter = 'j'            positi : negati =      3.6 : 1.0
#             start_letter = 'k'            positi : negati =      3.3 : 1.0
#             start_letter = 'n'            negati : positi =      3.3 : 1.0
#             start_letter = 'u'            negati : positi =      2.7 : 1.0
#              last_letter = 'k'            negati : positi =      2.7 : 1.0
#              last_letter = 'b'            negati : positi =      2.7 : 1.0
#             start_letter = 'e'            positi : negati =      2.6 : 1.0
# None
# Name :  hope  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  laugh  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  jealous  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  validated  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  helps  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  grand  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  slickest  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  playful  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  boost  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  fabulous  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  enemies  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  consolable  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  welcomed  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  clear  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  hilarious  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  support  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  fervent  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  desired  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  big  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  cherishes  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  carefree  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  lol  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  pray  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  willingness  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  coziness  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  happy  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  protected  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  save  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  adventurous  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  healthy  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  marvel  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  cherishing  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  daring  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  optimistic  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  congratulate  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  bliss  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  kills  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  daredevil  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  swiftly  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  vigilant  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  rewarding  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  raptured  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  astounds  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  secures  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  motivation  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  hug  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  god  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  breathtaking  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  enrage  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  rigorous  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  sincere  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  validating  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  embittered  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  eerie  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  compassionate  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  sophisticated  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  enslave  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  sparkling  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  legal  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  errors  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  honor  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  celebrated  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  fascinating  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  creative  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  relishing  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  tolerant  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  devoted  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  substantial  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  jeopardy  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  clean  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  rage  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  comfortable  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  soothe  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  supporting  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  vitamin  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  accidental  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  honouring  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  liked  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  awful  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  exploit  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  bitch  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  controversial  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  promote  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  enslaves  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  recommended  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  appeased  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  inspiration  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  green-wash  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  once-in-a-lifetime  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  invite  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  charming  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  stimulated  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  pleased  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  perfectly  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  green-washing  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  win  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  united  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  solves  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  blithe  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  backing  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  revives  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  strength  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  humour  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  promotes  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  rejoicing  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  clarifies  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  overjoyed  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  clarity  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  amuse  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  treasure  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  thankful  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  cherished  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  agog  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  ambitious  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  rageful  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  innovates  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  huge  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  praise  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  congratulation  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  hardier  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  pleasure  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  supports  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  winning  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  adventures  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  exploiting  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  wrathful  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  alive  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  advanced  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  benefitting  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  trust  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  funny  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  promoted  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  proud  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  commits  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  wins  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  launched  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  opportunities  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  excluded  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  honour  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  prospect  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  greenwashing  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  expel  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  absolves  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  determined  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  thanks  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  captivated  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  boosted  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  sympathetic  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  infatuated  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  tranquil  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  comedy  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  outstanding  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  attracting  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  jackasses  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  rape  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  masterpieces  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  bright  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  guilt  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  restored  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  protect  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  focused  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  grey  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  humourous  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  sincerity  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  noble  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  rewards  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  escaping  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  favors  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  envy  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  superior  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  sprightly  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  unbiased  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  courtesy  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  expelled  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  appease  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  robber  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  progress  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  certain  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  heaven  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  gag  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  impressive  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  acquit  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  agrees  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  boosting  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  commend  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  agreement  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  inquisitive  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  peacefully  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  honoring  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  benefits  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  praying  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  festive  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  gullibility  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  happiness  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  exhausted  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  innovation  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  emptiness  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  perfects  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  dreams  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  novel  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  brightest  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  applauds  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  serene  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  promised  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  calmed  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  enemy  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  boosts  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  honest  Calc_sentiment :  negative  Actual_sentiment :  positive
# negative

# %%
word='poonacha'
seclast_letter = word[-2:-1]
print(seclast_letter)
# Out:
# h
