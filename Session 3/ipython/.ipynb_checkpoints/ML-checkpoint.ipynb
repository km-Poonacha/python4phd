# %%
import csv
import nltk
import random

def feature_extractor(word):
    start_letter = word[0]
    last_letter = word[-1]
    no_letters = len(word)
    percentage_vowels = 0
    no_vowels = 0
    for letter in word:
        if letter in ['a','e','i','o','u']:
            no_vowels = no_vowels + 1
    if no_vowels:
        percentage_vowels = no_vowels/len(word)
    return {'start_letter' : start_letter,'last_letter' : last_letter, 'no_letters' : no_letters,'percentage_vowels': percentage_vowels}

def ML_train(LABEL_CSV):
    feature_list = []
    train_list =[]
    test_list = []
    #feature_row = []
    with open (LABEL_CSV,'rt',encoding='utf-8') as labelobj:
        label_list=csv.reader(labelobj)
        for label_data in label_list:
            word_features = feature_extractor(label_data[0])
            if int(label_data[1]) >= 0:
                feature_row = [word_features,'positive']
            else:
                feature_row = [word_features,'negative']
            feature_list.append(feature_row)
    random.shuffle(feature_list)    
    train_list = feature_list[:1500]
    test_list = feature_list[:-1500]
    print(train_list)
    classifier = nltk.NaiveBayesClassifier.train(train_list)
    print('Test accuracy of the classifier = ',nltk.classify.accuracy(classifier, test_list))
    print(classifier.show_most_informative_features())
    return classifier
    
    
def main():
    sentiment_csv = "C:/Users/kmpoo/Dropbox/HEC/Teaching/Python for PhD Mar 2018/python4phd/Session 3/Sent/word_sentiment.csv"
    print(feature_extractor('poonacha'))
    classifier = ML_train(sentiment_csv)
    # why not pass the word directly to ML_train ?
    print(classifier.classify(feature_extractor('poonacha')))
    # Can you tell me why it changes when we run this again ? 
    
          
main()
# Out:
# {'start_letter': 'p', 'last_letter': 'a', 'no_letters': 8, 'percentage_vowels': 0.5}
# [[{'start_letter': 'f', 'last_letter': 's', 'no_letters': 7, 'percentage_vowels': 0.2857142857142857}, 'positive'], [{'start_letter': 'e', 'last_letter': 'g', 'no_letters': 12, 'percentage_vowels': 0.4166666666666667}, 'positive'], [{'start_letter': 'j', 'last_letter': 's', 'no_letters': 6, 'percentage_vowels': 0.5}, 'positive'], [{'start_letter': 'p', 'last_letter': 'd', 'no_letters': 8, 'percentage_vowels': 0.375}, 'positive'], [{'start_letter': 's', 'last_letter': 'e', 'no_letters': 6, 'percentage_vowels': 0.3333333333333333}, 'negative'], [{'start_letter': 's', 'last_letter': 'h', 'no_letters': 7, 'percentage_vowels': 0.2857142857142857}, 'negative'], [{'start_letter': 'u', 'last_letter': 'l', 'no_letters': 14, 'percentage_vowels': 0.42857142857142855}, 'negative'], [{'start_letter': 's', 'last_letter': 's', 'no_letters': 8, 'percentage_vowels': 0.25}, 'negative'], [{'start_letter': 'v', 'last_letter': 's', 'no_letters': 7, 'percentage_vowels': 0.2857142857142857}, 'negative'], [{'start_letter': 'i', 'last_letter': 't', 'no_letters': 9, 'percentage_vowels': 0.3333333333333333}, 'negative'], [{'start_letter': 'v', 'last_letter': 'y', 'no_letters': 9, 'percentage_vowels': 0.4444444444444444}, 'positive'], [{'start_letter': 's', 'last_letter': 'n', 'no_letters': 6, 'percentage_vowels': 0.3333333333333333}, 'negative'], [{'start_letter': 'h', 'last_letter': 'e', 'no_letters': 9, 'percentage_vowels': 0.3333333333333333}, 'negative'], [{'start_letter': 'c', 'last_letter': 'g', 'no_letters': 8, 'percentage_vowels': 0.25}, 'negative'], [{'start_letter': 's', 'last_letter': 'r', 'no_letters': 8, 'percentage_vowels': 0.5}, 'positive'], [{'start_letter': 'f', 'last_letter': 'g', 'no_letters': 3, 'percentage_vowels': 0.3333333333333333}, 'negative'], [{'start_letter': 'f', 'last_letter': 'd', 'no_letters': 3, 'percentage_vowels': 0.3333333333333333}, 'negative'], [{'start_letter': 'l', 'last_letter': 'r', 'no_letters': 4, 'percentage_vowels': 0.5}, 'negative'], [{'start_letter': 'b', 'last_letter': 'l', 'no_letters': 9, 'percentage_vowels': 0.5555555555555556}, 'positive'], [{'start_letter': 'v', 'last_letter': 's', 'no_letters': 10, 'percentage_vowels': 0.4}, 'positive'], [{'start_letter': 'a', 'last_letter': 'r', 'no_letters': 5, 'percentage_vowels': 0.4}, 'negative'], [{'start_letter': 'd', 'last_letter': 'y', 'no_letters': 5, 'percentage_vowels': 0.2}, 'negative'], [{'start_letter': 'd', 'last_letter': 'd', 'no_letters': 11, 'percentage_vowels': 0.36363636363636365}, 'negative'], [{'start_letter': 'n', 'last_letter': 'y', 'no_letters': 5, 'percentage_vowels': 0.2}, 'negative'], [{'start_letter': 'm', 'last_letter': 'g', 'no_letters': 13, 'percentage_vowels': 0.3076923076923077}, 'negative'], [{'start_letter': 'o', 'last_letter': 's', 'no_letters': 3, 'percentage_vowels': 0.3333333333333333}, 'positive'], [{'start_letter': 'f', 'last_letter': 's', 'no_letters': 10, 'percentage_vowels': 0.3}, 'negative'], [{'start_letter': 'e', 'last_letter': 't', 'no_letters': 7, 'percentage_vowels': 0.42857142857142855}, 'negative'], [{'start_letter': 'w', 'last_letter': 'w', 'no_letters': 3, 'percentage_vowels': 0.3333333333333333}, 'positive'], [{'start_letter': 's', 'last_letter': 'y', 'no_letters': 7, 'percentage_vowels': 0.14285714285714285}, 'positive'], [{'start_letter': 'c', 'last_letter': 'e', 'no_letters': 11, 'percentage_vowels': 0.45454545454545453}, 'positive'], [{'start_letter': 'd', 'last_letter': 'd', 'no_letters': 8, 'percentage_vowels': 0.5}, 'negative'], [{'start_letter': 'm', 'last_letter': 'g', 'no_letters': 16, 'percentage_vowels': 0.3125}, 'negative'], [{'start_letter': 'r', 'last_letter': 'e', 'no_letters': 7, 'percentage_vowels': 0.5714285714285714}, 'positive'], [{'start_letter': 'w', 'last_letter': 'r', 'no_letters': 6, 'percentage_vowels': 0.3333333333333333}, 'negative'], [{'start_letter': 'c', 'last_letter': 's', 'no_letters': 9, 'percentage_vowels': 0.2222222222222222}, 'negative'], [{'start_letter': 'a', 'last_lette ...
# Test accuracy of the classifier =  0.6768916155419223
# Most Informative Features
#              last_letter = 'w'            positi : negati =      7.4 : 1.0
#              last_letter = 'o'            positi : negati =      6.3 : 1.0
#             start_letter = 'd'            negati : positi =      5.2 : 1.0
#             start_letter = 'u'            negati : positi =      3.4 : 1.0
#              last_letter = 'a'            positi : negati =      3.1 : 1.0
#             start_letter = 'j'            positi : negati =      2.9 : 1.0
#              last_letter = 'p'            negati : positi =      2.9 : 1.0
#              last_letter = 'b'            negati : positi =      2.9 : 1.0
#             start_letter = 'g'            positi : negati =      2.6 : 1.0
#        percentage_vowels = 0.38461538461538464 negati : positi =      2.5 : 1.0
# None
# positive

# %%
import csv
import nltk
import random

def feature_extractor(word):
    start_letter = word[0]
    last_letter = word[-1]
    no_letters = len(word)
    percentage_vowels = 0
    no_vowels = 0
    for letter in word:
        if letter in ['a','e','i','o','u']:
            no_vowels = no_vowels + 1
    if no_vowels:
        percentage_vowels = no_vowels/len(word)
    return {'start_letter' : start_letter,'last_letter' : last_letter, 'no_letters' : no_letters,'percentage_vowels': percentage_vowels}

def ML_train(LABEL_CSV):
    feature_list = []
    train_list =[]
    test_list = []
    #feature_row = []
    with open (LABEL_CSV,'rt',encoding='utf-8') as labelobj:
        label_list=csv.reader(labelobj)
        for label_data in label_list:
            word_features = feature_extractor(label_data[0])
            if int(label_data[1]) >= 0:
                feature_row = [word_features,'positive']
            else:
                feature_row = [word_features,'negative']
            feature_row.append(label_data[0])
            feature_list.append(feature_row)
    random.shuffle(feature_list)    
    train_list = feature_list[:1500]
    nt = [[features_dict[0], features_dict[1]] for features_dict in   train_list ]
    #print(nt)
    #devtest_list = feature_list[1200:1800]
    test_list = feature_list[:-1500]
    classifier = nltk.NaiveBayesClassifier.train(nt)
    print('Test accuracy of the classifier = ',nltk.classify.accuracy(classifier, nt))
    print(classifier.show_most_informative_features())
    dev_test(classifier, test_list)
    return classifier
    
def dev_test(classifier, devtest_list):
    dt = [[features_dict[0], features_dict[1]] for features_dict in   devtest_list ]
    for devtest_word in devtest_list:
        calc_sentiment = classifier.classify(devtest_word[0])
        if calc_sentiment != devtest_word[1]:
            print('Name : ',devtest_word[2],' Calc_sentiment : ',calc_sentiment, ' Actual_sentiment : ',devtest_word[1])
    
    
def main():
    sentiment_csv = "C:/Users/kmpoo/Dropbox/HEC/Teaching/Python for PhD Mar 2018/python4phd/Session 3/Sent/word_sentiment.csv"
    print(feature_extractor('poonacha'))
    classifier = ML_train(sentiment_csv)
    # why not pass the word directly to ML_train ?
    print(classifier.classify(feature_extractor('poonacha')))
    
    
          
main()
# Out:
# {'start_letter': 'p', 'last_letter': 'a', 'no_letters': 8, 'percentage_vowels': 0.5}
# Test accuracy of the classifier =  0.676
# Most Informative Features
#              last_letter = 'o'            positi : negati =      6.5 : 1.0
#             start_letter = 'y'            positi : negati =      6.5 : 1.0
#             start_letter = 'd'            negati : positi =      6.4 : 1.0
#             start_letter = 'n'            negati : positi =      4.9 : 1.0
#        percentage_vowels = 0.38461538461538464 negati : positi =      4.4 : 1.0
#        percentage_vowels = 0.6666666666666666 positi : negati =      4.1 : 1.0
#             start_letter = 'g'            positi : negati =      3.2 : 1.0
#        percentage_vowels = 0.2727272727272727 negati : positi =      3.2 : 1.0
#              last_letter = 'b'            negati : positi =      3.2 : 1.0
#               no_letters = 14             negati : positi =      3.2 : 1.0
# None
# Name :  untarnished  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  elation  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  awesome  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  jeopardy  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  fondness  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  accept  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  promoting  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  wins  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  grey  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  apologise  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  clarity  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  applauding  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  vitamin  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  inspired  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  triumphant  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  vague  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  sore  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  fire  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  spirited  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  smiling  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  stable  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  landmark  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  hysteria  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  matter  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  perfectly  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  compassionate  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  delight  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  expelling  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  vindicated  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  convinced  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  praising  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  axe  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  cruel  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  blesses  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  admiring  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  errors  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  absolved  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  calming  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  shares  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  steadfast  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  celebrating  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  blessing  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  attracting  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  perfects  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  cheery  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  celebrates  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  envy  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  provoke  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  shrew  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  jailed  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  poorer  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  alas  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  luck  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  absorbed  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  blithe  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  bless  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  lol  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  fond  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  exhausted  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  assets  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  sincerity  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  impress  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  irritate  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  ominous  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  saved  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  rigorously  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  popular  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  faith  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  embarrass  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  greenwashers  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  irresistible  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  solidarity  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  pray  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  pleased  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  revenge  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  fitness  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  bamboozle  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  sexy  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  ghost  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  asset  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  intrigues  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  visions  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  importance  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  clears  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  benefitting  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  improving  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  share  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  violates  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  rageful  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  favor  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  sincerely  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  anticipation  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  backs  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  calms  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  infatuation  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  progress  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  libelous  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  important  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  support  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  hate  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  revengeful  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  stimulating  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  exhilarated  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  winning  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  solving  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  refuse  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  supportive  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  prominent  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  poisoned  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  sincere  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  rescues  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  greed  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  chances  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  expel  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  resolved  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  confident  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  safely  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  devoted  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  fit  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  sunshine  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  cheered  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  enlightens  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  advanced  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  united  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  wishing  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  felonies  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  jackasses  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  capable  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  excuse  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  gratification  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  commend  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  consent  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  injustice  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  robust  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  gross  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  funny  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  conciliated  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  indecisive  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  eviction  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  boosting  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  highlight  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  lied  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  feeling  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  accuse  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  interested  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  hailed  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  thank  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  embarrassing  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  bliss  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  brave  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  impatient  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  fascinating  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  appreciation  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  reward  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  novel  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  sparkling  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  salient  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  intelligent  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  waste  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  top  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  violent  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  legally  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  exonerating  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  strong  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  matters  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  consents  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  secures  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  illegal  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  suspicious  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  virulent  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  honoured  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  agonising  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  legal  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  yucky  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  dear  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  brilliant  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  revives  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  inspiring  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  motivated  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  exposed  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  vitality  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  desired  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  exaggerating  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  pressure  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  laughing  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  lively  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  hug  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  tolerant  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  exploiting  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  accepted  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  help  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  ruined  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  pardon  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  treasures  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  favors  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  exposes  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  validating  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  prospect  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  mirthful  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  thoughtful  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  slick  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  error  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  fervent  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  jolly  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  improve  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  enlighten  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  pardons  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  picturesque  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  cleared  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  poor  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  apologizes  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  kinder  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  exaggerate  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  inspirational  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  hopefully  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  bereaves  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  smartest  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  greenwashing  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  buoyant  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  awards  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  favorites  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  substantially  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  cherishing  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  prays  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  lugubrious  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  embittered  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  loving  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  surviving  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  sorrowful  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  unbiased  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  laughting  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  tout  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  peacefully  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  astounds  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  blockbuster  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  comprehensive  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  indestructible  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  vision  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  optimism  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  erroneous  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  postpone  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  harmful  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  protected  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  invincible  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  astounding  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  praying  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  irrational  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  apologized  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  solution  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  reaches  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  charming  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  rewards  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  feeble  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  lovable  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  gullible  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  useful  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  dearly  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  supporter  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  resentful  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  fright  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  brisk  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  winwin  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  retained  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  lighthearted  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  vindicates  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  endorsement  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  desirous  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  inviting  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  abuses  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  overjoyed  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  backing  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  launched  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  accomplished  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  grieved  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  trusted  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  admired  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  triumph  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  enslave  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  spark  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  inspiration  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  conciliates  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  looses  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  clever  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  enemy  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  fatigues  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  pitied  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  appease  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  super  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  resolves  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  calm  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  lonesome  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  accident  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  beatific  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  imbecile  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  survived  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  awarded  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  protects  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  annoyance  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  axed  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  improved  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  fear  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  joyless  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  pained  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  loyal  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  cherishes  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  regretful  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  stunning  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  adopt  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  commended  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  enraged  Calc_sentiment :  positive  Actual_sentiment :  negative
# Name :  honest  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  backed  Calc_sentiment :  negative  Actual_sentiment :  positive
# Name :  fulfills  Calc_sentiment :  negative  Actual_sentiment :  positive
# positive
